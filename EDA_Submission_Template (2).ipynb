# %% [markdown]
# # **Project Name**    -EDA Submission Template

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing the Global Terrorism Dataset to understand patterns, trends, and key insights related to terrorist activities across the world. The dataset contains detailed information about various incidents, including date, location, type of attack, weapons used, target categories, terrorist groups involved, and the impact in terms of casualties and damage. The main objective of this analysis is to explore the data and extract meaningful insights that can help in understanding the nature and distribution of terrorism globally.
#
# The analysis begins with data exploration and understanding the structure of the dataset. Important variables such as year, country, region, attack type, number of people killed, and number of people wounded were selected for deeper analysis. Data cleaning was an essential step in this process, as the dataset contained missing and inconsistent values. These were handled using techniques such as removing null values, converting data types, and filtering relevant columns to ensure accurate analysis.
#
# Exploratory Data Analysis (EDA) was performed using various visualization techniques to identify patterns and relationships within the data. Bar charts and count plots were used to analyze the frequency of attacks over different years and regions. Scatter plots helped in understanding the relationship between the number of people killed and wounded in each attack. Pair plots provided a comprehensive view of how multiple variables interact with each other, while violin plots and density plots were used to study the distribution of casualties.
#
# The analysis revealed several important insights. It was observed that terrorist activities have increased significantly over certain periods, indicating fluctuations in global security conditions. Some regions were found to be more affected than others, highlighting geographical concentration of attacks. The data also showed that certain types of attacks, such as bombings and armed assaults, are more common. Additionally, there is a positive correlation between the number of people killed and wounded, suggesting that more severe attacks tend to result in higher overall casualties.
#
# Further analysis of terrorist groups and targets provided insights into the most frequently targeted sectors, such as civilians, military, and government institutions. This information is crucial for understanding the intent and impact of different terrorist organizations. The success rate of attacks was also analyzed, giving an idea about how often these incidents achieve their intended outcomes.
#
# Overall, this project demonstrates how data analysis and visualization techniques can be effectively used to uncover meaningful insights from complex datasets. The findings can help policymakers, researchers, and security agencies in making informed decisions and developing strategies to prevent and control terrorist activities. However, the analysis is limited by missing data and potential biases in reporting, which should be considered when interpreting the results.
#
# In conclusion, the Global Terrorism Dataset provides valuable information that, when analyzed properly, can contribute to a better understanding of global terrorism patterns and support efforts toward enhancing safety and security worldwide.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# Terrorism is a major global issue that affects the safety, economy, and stability of countries worldwide. Despite the availability of large amounts of data on terrorist incidents, it is difficult to clearly understand patterns, trends, and key factors influencing these attacks without proper analysis.
#
# The problem is to analyze the Global Terrorism Dataset to identify meaningful insights such as the most affected regions, common types of attacks, targets, and the overall impact in terms of casualties. The dataset contains missing and inconsistent values, which makes analysis challenging and requires proper data cleaning and preprocessing.
#
# The goal of this project is to use data analysis and visualization techniques to explore the dataset, uncover hidden patterns, and understand the relationship between different variables. This will help in gaining better insights into global terrorism trends and support decision-making for improving security and preventive measures.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main business objective of this project is to analyze the Global Terrorism Dataset to identify patterns, trends, and high-risk areas of terrorist activities. The goal is to generate actionable insights that can help governments, security agencies, and organizations make informed decisions for improving public safety and resource allocation.
#
# This analysis aims to:
#
# Identify the most affected regions and countries
# Understand common attack types and targets
# Analyze casualty patterns (killed and wounded)
# Evaluate trends over time
#
# By achieving these objectives, the project helps in risk assessment, strategic planning, and enhancing security measures to reduce the impact of terrorist activities.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv('Global Terrorism Data.csv', encoding='latin1')
# Out:
# /tmp/ipykernel_8787/4110224710.py:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Global Terrorism Data.csv', encoding='latin1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated(subset=['iyear','imonth','iday','city','country']).sum()
# Out:
# np.int64(33641)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the missing values
missing = df.isnull().sum()
missing[missing > 0].sort_values().plot(kind='barh', figsize=(10,8))
plt.title("Missing Values Count per Column")
plt.xlabel("Number of Missing Values")
plt.ylabel("Columns")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset used is the Global Terrorism Dataset, which contains information about terrorist incidents across the world.
#
# ✔ Key Points: The dataset includes over 180,000 records of terrorist attacks, It contains details like: Year, Month, Day of attack, Country and Region, Attack type and weapon used, Number of people killed and wounded, Attack success (successful or failed)

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 📊 Variables Description (Short)
# eventid → Unique ID of each attack
# iyear, imonth, iday → Date of incident
# country_txt, region_txt, city → Location details
# latitude, longitude → Geographic coordinates
# attacktype1_txt → Type of attack
# targtype1_txt → Target type
# weaptype1_txt → Weapon used
# gname → Terrorist group name
# nkill, nwound → Casualties (killed & injured)
# success → Attack success (1 = Yes, 0 = No)
# summary → Brief description of attack

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(df.nunique())
# Out:
# eventid       181691
# iyear             47
# imonth            13
# iday              32
# approxdate      2244
#                ...
# INT_LOG            3
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14306
# Length: 135, dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
import pandas as pd

# Load dataset
df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')

# Check basic info
print(df.shape)
print(df.info())

# Check missing values
print(df.isnull().sum())

# Drop columns with more than 50% missing values
df = df.dropna(axis=1, thresh=len(df)*0.5)

# Fill remaining missing values
df.fillna("Unknown", inplace=True)

# Check duplicates
print(df.duplicated().sum())

# Check unique values
print(df.nunique())
# Out:
# /tmp/ipykernel_8787/51845115.py:5: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')
# (181691, 135)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB
# None
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# => Data Manipulations:Loaded the dataset using pandas Checked dataset structure using info() and shape Identified missing values using isnull() Removed columns with more than 50% missing values Filled remaining null values with "Unknown" Checked for duplicate rows (none found) Analyzed unique values in each column

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
year_counts = df['iyear'].value_counts().sort_index()

plt.plot(year_counts)
plt.xlabel("Year")
plt.ylabel("Number of Attacks")
plt.title("Number of Terrorist Attacks per Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# => Line chart is best to show trend over time. It helps understand how attacks increase or decrease yearly

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# => Terrorist attacks increased rapidly after 2000 Peak observed around 2012–2014 Slight decline after that period

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# => Positive Impact: Helps governments and organizations plan security strategies Identify high-risk periods for better prevention Negative Growth Insight: Rapid increase in attacks shows growing instability High number of incidents can affect: Economy Tourism Public safety

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
top_countries = df['country_txt'].value_counts().head(10)

top_countries.plot(kind='bar')
plt.title("Top 10 Countries with Most Attacks")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# => A bar chart is used because it is best for comparing categorical data (countries) and clearly shows the top 10 countries with most attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Attacks are concentrated in a few countries. Some countries have significantly higher attacks, indicating high-risk regions. There is a clear difference between top and lower countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in risk analysis and better decision-making. Useful for security planning and investment strategies.
#
# Negative:
#
# High attacks can reduce investment and tourism. Causes business disruption and economic loss.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
top_countries.plot(kind='pie', autopct='%1.1f%%')
plt.title("Attack Distribution in Top Countries")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used to show the proportion/percentage distribution of attacks among the top countries, making it easy to see each country’s share.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A few countries hold a large percentage of total attacks. Some countries contribute very small shares. It shows how attacks are unevenly distributed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps identify high-risk countries for better planning. Useful for resource allocation and security focus.
#
# Negative:
#
# Countries with large shares may face low investment and tourism. Indicates instability, leading to economic and business risks.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
year_counts = df['iyear'].value_counts().sort_index()

year_counts.plot(kind='area',color='green')

plt.title("Trend of Attacks Over Time")
plt.xlabel("Year")
plt.ylabel("Attacks")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An area chart is used to show trends over time. It helps visualize how the number of attacks increases or decreases across years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows overall trend (increasing or decreasing attacks). Highlights peak years with maximum attacks. Reveals periods of rapid growth or decline.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in future planning and risk prediction. Useful for policy making and security improvements.
#
# Negative:
#
# Rising trend indicates increasing instability, affecting business growth. High attack periods can lead to economic loss and reduced investment.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Remove missing values
df_clean = df[['nkill', 'nwound']].dropna()

# Convert to numeric (in case of errors)
df_clean['nkill'] = pd.to_numeric(df_clean['nkill'], errors='coerce')
df_clean['nwound'] = pd.to_numeric(df_clean['nwound'], errors='coerce')

# Drop again if conversion created NaN
df_clean = df_clean.dropna()

# Plot
plt.scatter(df_clean['nkill'], df_clean['nwound'], color='green')

plt.xlabel("Number Killed")
plt.ylabel("Number Wounded")
plt.title("Killed vs Wounded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used to show the relationship between two numerical variables (nkill and nwound). It helps identify correlation and patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There may be a positive relationship (more killed → more wounded). Most points may cluster at low values, showing many small-scale attacks. Few points far from others indicate highly severe attacks (outliers).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in understanding attack severity. Useful for emergency planning and resource allocation.
#
# Negative:
#
# High casualty attacks indicate serious security risks. Can lead to economic loss, fear, and reduced business activity.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df['iyear'].plot(kind='hist', bins=30 , color='red')

plt.title("Distribution of Attacks by Year")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to show the distribution of attacks over years. It helps understand how frequently attacks occurred in different time periods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows which years have high concentration of attacks. Identifies peak periods with maximum frequency. Reveals whether attacks are increasing over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in trend analysis and forecasting risks. Useful for long-term planning and policy decisions.
#
# Negative:
#
# High frequency in recent years indicates growing instability. Can reduce investment, tourism, and economic growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
import seaborn as sns

# Clean data
nkill_clean = pd.to_numeric(df['nkill'], errors='coerce').dropna()

# Plot
sns.violinplot(y=nkill_clean)

plt.title("Distribution of Kills")
plt.ylabel("Number of Kills")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A violin plot is used to show the distribution and density of kills along with variability, combining features of boxplot and KDE.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most attacks have low number of kills (dense at lower values). Shows distribution spread and variability. Presence of outliers indicates rare but highly deadly attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in understanding severity patterns of attacks. Useful for risk assessment and emergency planning.
#
# Negative:
#
# High kill outliers indicate extreme threat events. Can cause economic loss, fear, and reduced business activity.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
success_counts = df['success'].value_counts()

plt.pie(success_counts, labels=['Success', 'Fail'], autopct='%1.1f%%')
plt.title("Attack Success Rate")

# Donut shape
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A donut (pie) chart is used to show the proportion of successful vs failed attacks. It clearly presents percentage distribution in a simple way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows the success rate of attacks. If success is higher, it indicates effective execution of attacks. If failure is higher, it reflects strong security measures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in evaluating security effectiveness. Useful for improving defense strategies and policies.
#
# Negative:
#
# High success rate indicates serious security gaps. Leads to fear, reduced investment, and economic loss.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(y='attacktype1_txt', data=df, order=df['attacktype1_txt'].value_counts().index)

plt.title("Types of Attacks")
plt.xlabel("Count")
plt.ylabel("Attack Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot (bar chart) is used to show the frequency of each attack type. It helps compare different categories easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Identifies the most common attack types. Shows which attack types are rare or less frequent. Highlights patterns in how attacks are typically carried out.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in focusing security measures on common attack types. Useful for resource allocation and prevention strategies.
#
# Negative:
#
# Frequent attack types indicate major vulnerabilities. Can lead to economic loss and operational risks if not controlled.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
status = df.groupby(['iyear', 'success']).size().unstack()

status.plot(kind='bar', stacked=True)

plt.title("Success vs Failure of Attacks by Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A stacked bar chart is used to compare success vs failure of attacks over time. It shows both total attacks and their distribution in one view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows how successful and failed attacks change over years. Helps identify years with high success rates. Reveals trends in security effectiveness over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps evaluate security improvements year by year. Useful for policy making and risk management.
#
# Negative:
#
# Increasing success rate indicates weak security systems. Leads to higher risk, reduced investment, and economic instability.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
top = df['country_txt'].value_counts().head(10)

plt.scatter(top.index, top.values, s=top.values*2,color='green')

plt.xticks(rotation=45)
plt.title("Top Countries (Bubble Size = Attacks)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bubble (scatter) chart is used to compare countries while also showing magnitude (number of attacks) using bubble size. It adds an extra layer of visualization beyond a simple bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Larger bubbles represent countries with higher number of attacks. Clearly highlights top high-risk countries. Shows a big gap between most affected and less affected countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps identify high-risk regions for better planning. Useful for investment decisions and security allocation.
#
# Negative:
#
# Countries with large bubbles may face low investment and tourism. Indicates instability, leading to economic and business losses.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Clean the data
nwound_clean = pd.to_numeric(df['nwound'], errors='coerce').dropna()

# Plot KDE
sns.kdeplot(nwound_clean, fill=True)

plt.title("Density of Wounded People")
plt.xlabel("Number of Wounded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A KDE (density) plot is used to show the distribution pattern of wounded people in a smooth way, better than a histogram.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most attacks have low number of wounded people (peak at lower values). Few cases show very high wounded counts (long tail). Indicates presence of rare but severe incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in understanding injury patterns for emergency planning. Useful for resource and medical preparedness.
#
# Negative:
#
# Severe incidents (high wounds) indicate high-risk situations. Can lead to economic loss, fear, and reduced business activity.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Clean data
nkill = pd.to_numeric(df['nkill'], errors='coerce')
nwound = pd.to_numeric(df['nwound'], errors='coerce')
success = pd.to_numeric(df['success'], errors='coerce')

# Calculate means (ignore NaN)
values = [
    nkill.mean(skipna=True),
    nwound.mean(skipna=True),
    success.mean(skipna=True)
]

labels = ['Kills', 'Wounds', 'Success']

# Convert to numpy array
values = np.array(values, dtype=float)

# Create angles
angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)

# Close the circle
values = np.concatenate((values, [values[0]]))
angles = np.concatenate((angles, [angles[0]]))

# Plot
plt.figure(figsize=(6,6))
plt.polar(angles, values)
plt.fill(angles, values, alpha=0.3)

plt.xticks(angles[:-1], labels)
plt.title("Radar Chart of Attack Features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A radar chart is used to compare multiple features (kills, wounds, success) in one view, showing their relative magnitude.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Compares average kills, wounds, and success rate. Helps identify which factor is highest or most dominant. Shows overall pattern of attack severity and effectiveness.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive:
#
# Helps in understanding key impact factors of attacks. Useful for planning security and emergency response.
#
# Negative:
#
# High values indicate serious threat levels. Can lead to economic loss, reduced investment, and instability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_df = df.select_dtypes(include=['int64','float64'])
corr = numeric_df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Global Terrorism Data", fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is used to visualize the correlation between numerical variables. It helps quickly identify strong and weak relationships using colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows positive and negative correlations between variables. Variables like kills and wounds may have a strong positive correlation. Many variables may have weak or no correlation, indicating independence.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Select important numeric columns
cols = ['nkill', 'nwound', 'iyear']

# Clean data
df_pair = df[cols].apply(pd.to_numeric, errors='coerce').dropna()

# Style
sns.set_style("whitegrid")

# Pair plot
sns.pairplot(
    df_pair,
    diag_kind='kde',
    corner=True,              # cleaner look (no duplicate plots)
    plot_kws={'alpha': 0.6}   # transparency for better visibility
)

plt.suptitle("Pair Plot of Key Features", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to compare multiple numerical variables and see their relationships and distributions in one view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a positive relation between nkill and nwound (more deaths → more injuries). Most attacks have low casualties, but few have very high values (outliers). Some years show higher attack impact, indicating variation over time.

# %% [markdown]
# # **Applying 5 ML Technique**

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')

# Show first rows
print(df.head())

# Select important columns (drop missing values)
df = df[['nkill', 'nwound', 'success', 'iyear', 'country_txt']]
df = df.dropna()
# Out:
# /tmp/ipykernel_2461/3429576962.py:5: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %% [markdown]
# ## **Regression (Predict Number of Kills)**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['nwound', 'iyear']]
y = df['nkill']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("Sample Predictions:", pred[:5])
# Out:
# Sample Predictions: [1.66999523 1.655732   1.55113496 1.66048641 1.66999523]

# %% [markdown]
# ## **Classification (Attack Success Prediction)**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X = df[['nkill', 'nwound', 'iyear']]
y = df['success']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.8822351656352384

# %% [markdown]
# ## **Clustering (Group Similar Attacks)**

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X = df[['nkill', 'nwound']]

kmeans = KMeans(n_clusters=3)
df['cluster'] = kmeans.fit_predict(X)

plt.scatter(df['nkill'], df['nwound'], c=df['cluster'])
plt.xlabel("Kills")
plt.ylabel("Wounds")
plt.title("Clustering of Attacks")
plt.show()

# %% [markdown]
# ## **Time Series Analysis (Attacks per Year)**

# %%
yearly = df.groupby('iyear').size()

yearly.plot()
plt.title("Attacks Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# ## **Anomaly Detection (Unusual Attacks)**

# %%
from sklearn.ensemble import IsolationForest

X = df[['nkill', 'nwound']]

model = IsolationForest(contamination=0.01)
df['anomaly'] = model.fit_predict(X)

print(df[df['anomaly'] == -1].head())  # Show anomalies
# Out:
#       nkill  nwound  success  iyear     country_txt  cluster  anomaly
# 1200    2.0   130.0        1   1972  United Kingdom        0       -1
# 1314   26.0    72.0        1   1972          Israel        0       -1
# 1342   81.0     0.0        1   1972   South Vietnam        0       -1
# 1789    1.0   238.0        1   1973  United Kingdom        0       -1
# 2138   30.0    50.0        1   1973           Italy        0       -1

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective (reducing and managing terrorist activities), the client (government/security agencies) should:
# Focus on High-Risk Areas
# Identify countries/regions with frequent attacks and increase security, surveillance, and intelligence operations there.
# Target Common Attack Types & Weapons
# Since some attack types (like bombings) are more frequent, stricter control on explosives and monitoring suspicious activities is needed.
# Improve Predictive Analysis
# Use historical data to predict future attack patterns and prepare preventive strategies in advance.
# Strengthen Emergency Response Systems
# Improve medical response and disaster management to reduce deaths and injuries during attacks.
# Increase Awareness & Training
# Educate citizens and train security forces to respond quickly and effectively.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# From the analysis of the dataset, we observed that terrorist attacks are not evenly distributed and certain regions, attack types, and time periods show higher activity. Most attacks result in low casualties, but some extreme events cause heavy damage.
#
# By using data-driven insights such as identifying high-risk zones, understanding attack patterns, and improving response strategies, authorities can take better decisions to reduce the impact of terrorism.
#
# Overall, data analysis plays a crucial role in enhancing security planning, minimizing risks, and protecting lives.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
